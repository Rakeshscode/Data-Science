# %% [markdown]
# <a href="https://colab.research.google.com/github/Rakeshscode/Data-Science/blob/main/Copy_of_Unit8ExercisesSF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unit 8 Exercises: The Art of BART
#
# These exercises are grouped into two parts:
#
# - Questions on the nature of decision trees, random forests, and BART models
# - An oppurtunity to practice implementing and analyzing a BART model.
#
# Enjoy!

# %% [markdown]
# ## Bartian Theory

# %% [markdown]
# **Task1**:
#
# Draw a decision tree--on a physical piece of paper--that predicts how many calories you burn in a day, using time you spent exercising that day (in minutes) as a predictor.
#
# To help you understand what you're doing with this tree, seperately create an x/y plot with time exercising as x, and calories burned as y.
#
# If this seems to easy, then add another variable or two (type of exercise?), and/or increase the depth of your tree.
#
# You do not have to show me or turn in your tree to earn credit for this question, although I would like to see your drawing.

# %% [markdown]
# **Task2**:
#
# What is a decision tree? How do they work?

# %% [markdown]
# A decision tree is a model that makes predictions by splitting data into branches based on feature values. It works like a flowchart, where each internal node represents a decision, branches show possible outcomes, and leaves provide final predictions.

# %% [markdown]
# **Task3**:
#
# What does the "depth" of a decision tree mean?
#
# How do I know if a tree is too deep, or not deep enough?

# %% [markdown]
# The "depth" of a decision tree is the number of levels from the root to the deepest leaf. A tree is too deep if it overfits the training data and too shallow if it underfits, meaning it misses important patterns.

# %% [markdown]
# **Task4:**
#
# How are BART models similar and different from a decision tree?

# %% [markdown]
# BART  models, like decision trees, use tree-based architectures for prediction. BART, on the other hand, is an ensemble of many small trees that employs Bayesian inference to estimate uncertainty and generally outperforms a single deep decision tree.

# %% [markdown]
# **Task5**:
#
# Why would we use a BART model instead of a decision tree?

# %% [markdown]
# We use a BART model instead of a decision tree because BART reduces overfitting, provides better uncertainty estimates, and captures complex relationships more effectively by averaging multiple trees.

# %% [markdown]
# ## Bartian Penguins

# %% [markdown]
# **Task6**:
#
# Create a BART model that uses flipper length, bill depth, and bill length to predict body mass in penguins, and make a ppc to check its fit
#
# Code for loading the data is below. You'll need to do everything else yourself.
#
# Remember to use my notes as a reference, and to copy and paste from them when it makes sense to.
#
# Oh, and try a normal likelihood.

# %%
#drop the incomplete rows from the dat
import arviz as az
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pymc as pm
import seaborn as sns
from sklearn import tree
# !pip install pymc-bart
# !pip install preliz
import pymc_bart as pmb
import preliz as pz
url="https://raw.githubusercontent.com/thedarredondo/data-science-fundamentals/main/Data/penguins.csv"
penguins = pd.read_csv(url).dropna()

# %%
features = ["flipper_length", "bill_length","bill_depth"]

X = penguins[features]
Y = penguins["body_mass"].to_numpy()

# %%
with pm.Model() as model_octps:
    s = pm.HalfNormal('s',1000)
    μ_ = pmb.BART("μ_", X, np.log(Y), m=50)
    μ = pm.Deterministic("μ",pm.math.exp(μ_))
    y = pm.Normal("y", mu=μ, sigma=s,  observed=Y)
    idata_octps = pm.sample(compute_convergence_checks=False)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
pm.sample_posterior_predictive(idata_octps,model_octps, extend_inferencedata=True)
az.plot_ppc(idata_octps, num_pp_samples=100, colors=["C1", "C0", "C1"])
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Axes: xlabel='y'>

# %% [markdown]
# **Task7**:
#
# Plot flipper length versus body mass,
#
# and then plot the posterior predictve from the model over the data.
# You're going to copy paste the plotting code from the notes, fyi.

# %%
posterior_mean = idata_octps.posterior["μ"]

μ_hdi = az.hdi(ary=idata_octps, group="posterior", var_names=["μ"], hdi_prob=0.74)
pps = az.extract(
    idata_octps, group="posterior_predictive", var_names=["y"]
).T

# %%
Xn = X.to_numpy()

# %%
idx = np.argsort(Xn[:, 0])
fig, ax = plt.subplots()

az.plot_hdi(
    x=Xn[:, 0],
    y=pps,
    ax=ax,
    hdi_prob=0.93,
    fill_kwargs={"alpha": 0.3, "label": r"Posterior Predictive HDI"},
)

az.plot_hdi(
    x=Xn[:, 0],
    y=posterior_mean,
    ax=ax,
    hdi_prob=0.74,
    fill_kwargs={"alpha": 0.6, "label": r"Mean HDI"},
)
ax.plot(penguins["flipper_length"], penguins["body_mass"], "o", c="C0", label="Raw Data")
ax.legend(loc="lower right")
ax.set(
    title="Posterior Predictive",
    xlabel="flipper_length",
    ylabel="body_mass",
);
# Out:
# /usr/local/lib/python3.11/dist-packages/arviz/plots/hdiplot.py:166: FutureWarning: hdi currently interprets 2d data as (draw, shape) but this will change in a future release to (chain, draw) for coherence with other functions
#   hdi_data = hdi(y, hdi_prob=hdi_prob, circular=circular, multimodal=False, **hdi_kwargs)

# %% [markdown]
# **Task8**:
#
# Interpret the plot above in context. Do you think it captures the true association between flipper length and body mass in penguins? Why or why not? Make sure to reference specific things you see in the plot.

# %% [markdown]
# The posterior predictive plot suggests that the BART model captures the general trend between flipper length and body mass, as the mean prediction follows the data closely. However, the predictive intervals widen in some areas, indicating higher uncertainty where data is sparse, suggesting potential room for improvement.

# %% [markdown]
# **Task9**:
#
# Create partial depnedence plots (pdps), individual conditional expectation (ice) plots, and a variable importance plot for the BARTpenguin model.

# %%
pmb.plot_pdp(μ_, X, Y, grid=(1, 5), func=np.exp, figsize = (12,6))
# Out:
# array([<Axes: xlabel='flipper_length'>, <Axes: xlabel='bill_length'>,
#        <Axes: xlabel='bill_depth'>], dtype=object)

# %%
pmb.plot_ice( μ_, X, Y, grid=(1, 5), func=np.exp, figsize = (12,6))
# Out:
# array([<Axes: xlabel='flipper_length'>, <Axes: xlabel='bill_length'>,
#        <Axes: xlabel='bill_depth'>], dtype=object)

# %%
vi_counties = pmb.compute_variable_importance(idata_octps, μ_, X)
pmb.plot_variable_importance(vi_counties)
# Out:
# <Axes: ylabel='R²'>

# %% [markdown]
# **Task10**:
#
# Using the above plots, make an argument about which variable(s) is/are most important in predicting body mass in penguins.
#
# What is the relationship for each variable to body mass, when you take the other variables into account?
#
# Is that relationship complicated by interactions between variables? How do you know?
#
# Make sure to reference specific things you see in each plot, to justify your decisions and comments.

# %% [markdown]
# The variable importance plot indicates that flipper length is the most significant predictor of body mass. The ICE and partial dependence plots confirm this, showing a strong linear relationship with a steep slope, suggesting a direct correlation. While bill length and bill depth also contribute, their relationships are less consistent, with more variability in their slopes, hinting at possible interactions. This variability suggests that bill length and depth may interact with each other or with an unknown third variable, complicating their relationship with body mass. The differing slopes in the ICE plots further support the presence of these interactions, as individual lines diverge rather than following a single trend.
